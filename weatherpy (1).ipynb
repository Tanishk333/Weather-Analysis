# %%
import pandas as pd-

# %%
weather = pd.read_csv("pune.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION       NAME  PRCP  TAVG  TMAX  TMIN
# DATE
# 2014-08-09  IN012190100  POONA, IN  0.08    76  83.0   NaN
# 2014-08-10  IN012190100  POONA, IN  0.02    76  83.0   NaN
# 2014-08-11  IN012190100  POONA, IN  0.02    75  83.0   NaN
# 2014-08-12  IN012190100  POONA, IN  0.01    75  86.0   NaN
# 2014-08-13  IN012190100  POONA, IN  0.00    76   NaN   NaN
# ...                 ...        ...   ...   ...   ...   ...
# 2024-08-03  IN012190100  POONA, IN  0.63    75   NaN  73.0
# 2024-08-04  IN012190100  POONA, IN  0.63    75   NaN  72.0
# 2024-08-05  IN012190100  POONA, IN  1.54    76   NaN  73.0
# 2024-08-06  IN012190100  POONA, IN  0.20    76   NaN  72.0
# 2024-08-07  IN012190100  POONA, IN  0.00    77   NaN  72.0
#
# [3638 rows x 6 columns]

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.664376
# TAVG       0.000000
# TMAX       0.817482
# TMIN       0.136888
# dtype: float64

# %%
# remove the coloum which is ireelevant
core_weather = weather[["PRCP", "TMAX", "TMIN"]].copy()

# %%
core_weather.columns = ["precip", "temp_max", "temp_min"]

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      2417
# temp_max    2974
# temp_min     498
# dtype: int64

# %%
core_weather
# Out:
#             precip  temp_max  temp_min
# DATE
# 2014-08-09    0.08      83.0       NaN
# 2014-08-10    0.02      83.0       NaN
# 2014-08-11    0.02      83.0       NaN
# 2014-08-12    0.01      86.0       NaN
# 2014-08-13    0.00       NaN       NaN
# ...            ...       ...       ...
# 2024-08-03    0.63       NaN      73.0
# 2024-08-04    0.63       NaN      72.0
# 2024-08-05    1.54       NaN      73.0
# 2024-08-06    0.20       NaN      72.0
# 2024-08-07    0.00       NaN      72.0
#
# [3638 rows x 3 columns]

# %%
# check if any null value is remaining
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip      0.664376
# temp_max    0.817482
# temp_min    0.136888
# dtype: float64

# %%
core_weather["temp_max"].value_counts()
# Out:
# temp_max
# 87.0     47
# 86.0     47
# 91.0     47
# 89.0     47
# 88.0     45
# 85.0     39
# 82.0     33
# 90.0     33
# 83.0     31
# 92.0     28
# 93.0     27
# 94.0     26
# 84.0     24
# 100.0    18
# 80.0     16
# 81.0     16
# 99.0     13
# 95.0     13
# 102.0    12
# 79.0     12
# 97.0     12
# 96.0     11
# 98.0     10
# 101.0    10
# 103.0    10
# 78.0      8
# 104.0     7
# 77.0      7
# 105.0     6
# 75.0      2
# 76.0      2
# 66.0      1
# 73.0      1
# 106.0     1
# 107.0     1
# 74.0      1
# Name: count, dtype: int64

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2014-08-19     NaN      91.0       NaN
# 2014-08-20     NaN      91.0       NaN
# 2014-09-14     NaN      85.0       NaN
# 2014-09-15     NaN      86.0       NaN
# 2014-09-16     NaN      87.0       NaN
# ...            ...       ...       ...
# 2024-06-03     NaN       NaN      77.0
# 2024-07-14     NaN       NaN      71.0
# 2024-07-15     NaN       NaN      74.0
# 2024-07-16     NaN       NaN      73.0
# 2024-07-21     NaN       NaN      73.0
#
# [2417 rows x 3 columns]

# %%
# as you see in above data precipitation is missing at 14-8-19 so we will chext what is the precipitation values before this
core_weather.loc["2014-08-10":"2014-09-19",:]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2014-08-10    0.02      83.0       NaN
# 2014-08-11    0.02      83.0       NaN
# 2014-08-12    0.01      86.0       NaN
# 2014-08-13    0.00       NaN       NaN
# 2014-08-14    0.00      85.0       NaN
# 2014-08-15    0.04      83.0       NaN
# 2014-08-16    0.00      82.0       NaN
# 2014-08-17    0.12      84.0       NaN
# 2014-08-18    0.00      88.0       NaN
# 2014-08-19     NaN      91.0       NaN
# 2014-08-20     NaN      91.0       NaN
# 2014-08-21    0.08      91.0       NaN
# 2014-08-22    0.16      89.0       NaN
# 2014-08-23    1.30      89.0       NaN
# 2014-08-24    1.02      88.0       NaN
# 2014-08-25    2.48      90.0       NaN
# 2014-08-26    0.00      82.0       NaN
# 2014-08-27    0.24      82.0       NaN
# 2014-08-28    0.08      82.0       NaN
# 2014-08-29    0.20      85.0       NaN
# 2014-08-30    0.91      85.0       NaN
# 2014-08-31    0.00      81.0       NaN
# 2014-09-01    0.59      77.0       NaN
# ...

# %%
# in this we can replace all the null values with the 0 as when we see in the data we can analyze that most of the time precip is 0 and not happening so we replace it by 0 
core_weather["precip"] = core_weather["precip"].fillna(0)

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip         0
# temp_max    2974
# temp_min     498
# dtype: int64

# %%
core_weather[pd.isnull(core_weather["temp_max"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2014-08-13    0.00       NaN       NaN
# 2014-09-20    0.08       NaN       NaN
# 2014-12-04    0.00       NaN       NaN
# 2015-01-30    0.00       NaN       NaN
# 2015-03-28    0.00       NaN      69.0
# ...            ...       ...       ...
# 2024-08-03    0.63       NaN      73.0
# 2024-08-04    0.63       NaN      72.0
# 2024-08-05    1.54       NaN      73.0
# 2024-08-06    0.20       NaN      72.0
# 2024-08-07    0.00       NaN      72.0
#
# [2974 rows x 3 columns]

# %%
core_weather.loc["2014-08-10":"2014-09-30",:]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2014-08-10    0.02      83.0       NaN
# 2014-08-11    0.02      83.0       NaN
# 2014-08-12    0.01      86.0       NaN
# 2014-08-13    0.00       NaN       NaN
# 2014-08-14    0.00      85.0       NaN
# 2014-08-15    0.04      83.0       NaN
# 2014-08-16    0.00      82.0       NaN
# 2014-08-17    0.12      84.0       NaN
# 2014-08-18    0.00      88.0       NaN
# 2014-08-19    0.00      91.0       NaN
# 2014-08-20    0.00      91.0       NaN
# 2014-08-21    0.08      91.0       NaN
# 2014-08-22    0.16      89.0       NaN
# 2014-08-23    1.30      89.0       NaN
# 2014-08-24    1.02      88.0       NaN
# 2014-08-25    2.48      90.0       NaN
# 2014-08-26    0.00      82.0       NaN
# 2014-08-27    0.24      82.0       NaN
# 2014-08-28    0.08      82.0       NaN
# 2014-08-29    0.20      85.0       NaN
# 2014-08-30    0.91      85.0       NaN
# 2014-08-31    0.00      81.0       NaN
# 2014-09-01    0.59      77.0       NaN
# ...

# %%
core_weather = core_weather.fillna(method="ffill")
# Out:
# C:\Users\tanis\AppData\Local\Temp\ipykernel_14184\3127936549.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   core_weather = core_weather.fillna(method="ffill")

# %%
core_weather = core_weather.fillna(method="bfill")
# Out:
# C:\Users\tanis\AppData\Local\Temp\ipykernel_14184\901805323.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   core_weather = core_weather.fillna(method="bfill")

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.loc["2015-08-10":"2015-09-30",:]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2015-08-10    0.01      85.0      71.0
# 2015-08-11    0.00      87.0      70.0
# 2015-08-12    0.12      82.0      71.0
# 2015-08-13    0.00      81.0      71.0
# 2015-08-14    0.12      85.0      71.0
# 2015-08-15    0.01      86.0      71.0
# 2015-08-16    0.00      86.0      70.0
# 2015-08-17    0.03      87.0      69.0
# 2015-08-18    0.00      87.0      71.0
# 2015-08-19    0.00      88.0      69.0
# 2015-08-20    0.00      89.0      68.0
# 2015-08-21    0.00      89.0      71.0
# 2015-08-22    0.00      89.0      71.0
# 2015-08-23    0.01      86.0      70.0
# 2015-08-24    0.01      85.0      71.0
# 2015-08-25    0.00      82.0      70.0
# 2015-08-26    0.08      86.0      71.0
# 2015-08-27    0.00      82.0      71.0
# 2015-08-28    0.08      82.0      71.0
# 2015-08-29    0.20      87.0      71.0
# 2015-08-30    0.00      84.0      71.0
# 2015-08-31    0.02      87.0      69.0
# 2015-09-01    0.01      87.0      71.0
# ...

# %%
# we are checking datatypes here
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['2014-08-09', '2014-08-10', '2014-08-11', '2014-08-12', '2014-08-13',
#        '2014-08-14', '2014-08-15', '2014-08-16', '2014-08-17', '2014-08-18',
#        ...
#        '2024-07-29', '2024-07-30', '2024-07-31', '2024-08-01', '2024-08-02',
#        '2024-08-03', '2024-08-04', '2024-08-05', '2024-08-06', '2024-08-07'],
#       dtype='object', name='DATE', length=3638)

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index
# Out:
# DatetimeIndex(['2014-08-09', '2014-08-10', '2014-08-11', '2014-08-12',
#                '2014-08-13', '2014-08-14', '2014-08-15', '2014-08-16',
#                '2014-08-17', '2014-08-18',
#                ...
#                '2024-07-29', '2024-07-30', '2024-07-31', '2024-08-01',
#                '2024-08-02', '2024-08-03', '2024-08-04', '2024-08-05',
#                '2024-08-06', '2024-08-07'],
#               dtype='datetime64[ns]', name='DATE', length=3638, freq=None)

# %%
core_weather.index.year
# Out:
# Index([2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014,
#        ...
#        2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024],
#       dtype='int32', name='DATE', length=3638)

# %%
# Check for missing value defined in data documentation as in noacc doc it is define that where 9999 entry in that data is not recieved or missing so we check if we have 9999 or not
core_weather.apply(lambda x: (x == 9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather[["temp_max", "temp_min"]].plot()
# this is plot our minimium and maximum data day by day with the help of plot() func in pandas library
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# this help us to find in which day our data is missing
# Out:
# DATE
# 2014    145
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    362
# 2022    365
# 2023    364
# 2024    210
# Name: count, dtype: int64

# %%
core_weather["precip"].plot()
# plot a precipitation table in the bar chart to check weather our data is right or not
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 2014    10.05
# 2015    23.46
# 2016    23.03
# 2017    34.89
# 2018    15.65
# 2019    51.90
# 2020    37.27
# 2021    29.18
# 2022    36.40
# 2023    37.24
# 2024    27.16
# Name: precip, dtype: float64

# %%
core_weather.groupby(core_weather.index.year).apply(lambda x: x["precip"].sum()).plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()
# Out:
#       precip  temp_max  temp_min
# DATE
# 2014   10.05   12554.0    9669.0
# 2015   23.46   32786.0   23352.0
# 2016   23.03   31925.0   23614.0
# 2017   34.89   32048.0   23711.0
# 2018   15.65   32522.0   23726.0
# 2019   51.90   32120.0   24067.0
# 2020   37.27   32340.0   24190.0
# 2021   29.18   31543.0   23870.0
# 2022   36.40   31290.0   23925.0
# 2023   37.24   31944.0   23742.0
# 2024   27.16   20162.0   14008.0

# %%
core_weather["target"]=core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2014-08-09    0.08      83.0      71.0    83.0
# 2014-08-10    0.02      83.0      71.0    83.0
# 2014-08-11    0.02      83.0      71.0    86.0
# 2014-08-12    0.01      86.0      71.0    86.0
# 2014-08-13    0.00      86.0      71.0    85.0
# ...            ...       ...       ...     ...
# 2024-08-03    0.63      81.0      73.0    81.0
# 2024-08-04    0.63      81.0      72.0    81.0
# 2024-08-05    1.54      81.0      73.0    81.0
# 2024-08-06    0.20      81.0      72.0    81.0
# 2024-08-07    0.00      81.0      72.0     NaN
#
# [3638 rows x 4 columns]

# %%
core_weather=core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 2014-08-09    0.08      83.0      71.0    83.0
# 2014-08-10    0.02      83.0      71.0    83.0
# 2014-08-11    0.02      83.0      71.0    86.0
# 2014-08-12    0.01      86.0      71.0    86.0
# 2014-08-13    0.00      86.0      71.0    85.0
# ...            ...       ...       ...     ...
# 2024-08-02    0.43      81.0      72.0    81.0
# 2024-08-03    0.63      81.0      73.0    81.0
# 2024-08-04    0.63      81.0      72.0    81.0
# 2024-08-05    1.54      81.0      73.0    81.0
# 2024-08-06    0.20      81.0      72.0    81.0
#
# [3637 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge
reg=Ridge(alpha=.1)
# imported the ridge regression model from sklearn and then i initialized the model into this variable reg

# %%
predictors=["precip","temp_max","temp_min"]

# %%
train = core_weather.loc[:"2022-12-31"]
# so we split our data in a training set and a learning set so data til 22-12-31 is our training set

# %%
test=core_weather.loc["2023-01-01":]

# %%
reg.fit(train[predictors],train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions=reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"],predictions)
# Out:
# 0.46735831230458713

# %%
  # this ,means on average we were about 0.46 degree off the actual temperatur

# %%
import matplotlib.pyplot as plt

# %%
x=core_weather.loc["2024-07-01":"2024-08-01", 'precip']

# %%
y=core_weather.loc["2024-07-01":"2024-08-01"].index

# %%
plt.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0x196ce5cd700>,
# ...
#  [Text(1.0997905902400793, 0.021462935944981422, '2024-07-01 00:00:00'),
#   Text(1.0966510382328745, 0.08577004338788068, '2024-07-02 00:00:00'),
#   Text(1.068085370557532, 0.26304684221822466, '2024-07-03 00:00:00'),
#   Text(1.0262317121816675, 0.39604099903000356, '2024-07-04 00:00:00'),
#   Text(1.0223189570911189, 0.4060344196889315, '2024-07-05 00:00:00'),
#   Text(1.0152377054851711, 0.4234293345544271, '2024-07-06 00:00:00'),
#   Text(1.0024110634506305, 0.45295922539647676, '2024-07-07 00:00:00'),
#   Text(0.9933822002683467, 0.4724317984535107, '2024-07-08 00:00:00'),
#   Text(0.9093661409605851, 0.61891293545575, '2024-07-09 00:00:00'),
#   Text(0.803919537019321, 0.7508084829026911, '2024-07-10 00:00:00'),
#   Text(0.803919537019321, 0.7508084829026911, '2024-07-11 00:00:00'),
#   Text(0.789116897953201, 0.7663514346334308, '2024-07-12 00:00:00'),
#   Text(0.7740138065595357, 0.7816026018733676, '2024-07-13 00:00:00'),
# ...

# %%
x1=core_weather.loc["2024-02-01":"2024-07-01", 'precip']

# %%
y1=core_weather.loc["2024-02-01":"2024-07-01"].index

# %%
plt.pie(x1,labels=y1)
# Out:
# ([<matplotlib.patches.Wedge at 0x196ce691ca0>,
# ...
#  [Text(1.1, 0.0, '2024-02-01 00:00:00'),
#   Text(1.1, 0.0, '2024-02-02 00:00:00'),
#   Text(1.1, 0.0, '2024-02-03 00:00:00'),
#   Text(1.1, 0.0, '2024-02-04 00:00:00'),
#   Text(1.1, 0.0, '2024-02-05 00:00:00'),
#   Text(1.1, 0.0, '2024-02-06 00:00:00'),
#   Text(1.1, 0.0, '2024-02-07 00:00:00'),
#   Text(1.1, 0.0, '2024-02-08 00:00:00'),
#   Text(1.1, 0.0, '2024-02-09 00:00:00'),
#   Text(1.1, 0.0, '2024-02-10 00:00:00'),
#   Text(1.1, 0.0, '2024-02-11 00:00:00'),
#   Text(1.1, 0.0, '2024-02-12 00:00:00'),
#   Text(1.1, 0.0, '2024-02-13 00:00:00'),
#   Text(1.1, 0.0, '2024-02-14 00:00:00'),
#   Text(1.1, 0.0, '2024-02-15 00:00:00'),
#   Text(1.1, 0.0, '2024-02-16 00:00:00'),
#   Text(1.1, 0.0, '2024-02-17 00:00:00'),
#   Text(1.1, 0.0, '2024-02-18 00:00:00'),
#   Text(1.1, 0.0, '2024-02-19 00:00:00'),
#   Text(1.1, 0.0, '2024-02-20 00:00:00'),
#   Text(1.1, 0.0, '2024-02-21 00:00:00'),
#   Text(1.1, 0.0, '2024-02-22 00:00:00'),
# ...

# %%
combined=pd.concat([test["target"],pd.Series(predictions,index=test.index)],axis=1)
combined.columns=["actual","predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2023-01-01    81.0    81.366813
# 2023-01-02    81.0    81.367324
# 2023-01-03    81.0    81.366813
# 2023-01-04    81.0    81.366045
# 2023-01-05    81.0    81.365533
# ...            ...          ...
# 2024-08-02    81.0    81.331372
# 2024-08-03    81.0    81.316773
# 2024-08-04    81.0    81.317029
# 2024-08-05    81.0    81.251515
# 2024-08-06    81.0    81.347865
#
# [573 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-7.17120247e-02,  9.47561664e-01, -2.55818006e-04])

# %%
def create_predictions(predictors,core_weather,ref):
    train=core_weather.loc[:"2022-12-31"]
    test=core_weather.loc["2023-01-01":]
    reg.fit(train[predictors],train["target"])
    predictions=reg.predict(test[predictors])
    error=mean_absolute_error(test["target"],predictions)
    combined=pd.concat([test["target"],pd.Series(predictions,index=test.index)],axis=1)
    combined.columns=["actual","predictions"]
    return error,combined

# %%
core_weather["month_max"]=core_weather["temp_max"].rolling(30).mean()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max
# DATE
# 2014-08-09    0.08      83.0      71.0    83.0        NaN
# 2014-08-10    0.02      83.0      71.0    83.0        NaN
# 2014-08-11    0.02      83.0      71.0    86.0        NaN
# 2014-08-12    0.01      86.0      71.0    86.0        NaN
# 2014-08-13    0.00      86.0      71.0    85.0        NaN
# ...            ...       ...       ...     ...        ...
# 2024-08-02    0.43      81.0      72.0    81.0       99.9
# 2024-08-03    0.63      81.0      73.0    81.0       99.2
# 2024-08-04    0.63      81.0      72.0    81.0       98.5
# 2024-08-05    1.54      81.0      73.0    81.0       97.8
# 2024-08-06    0.20      81.0      72.0    81.0       97.1
#
# [3637 rows x 5 columns]

# %%
core_weather["month_day_max"]=core_weather["month_max"]/core_weather["temp_max"]

# %%
core_weather["max_min"]=core_weather["temp_max"]/core_weather["temp_min"]

# %%
predictors=["precip","temp_max","temp_min","month_max","month_day_max","max_min"]

# %%
core_weather=core_weather.iloc[30:,:].copy()

# %%
error,combined=create_predictions(predictors,core_weather,reg)

# %%
error
# Out:
# 0.4200679579621137

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 2014-09-08    0.02      80.0      71.0    82.0  84.566667       1.057083
# 2014-09-09    0.03      82.0      71.0    83.0  84.533333       1.030894
# 2014-09-10    0.12      83.0      71.0    82.0  84.533333       1.018474
# 2014-09-11    0.01      82.0      71.0    83.0  84.400000       1.029268
# 2014-09-12    0.00      83.0      71.0    86.0  84.300000       1.015663
# ...            ...       ...       ...     ...        ...            ...
# 2024-08-02    0.43      81.0      72.0    81.0  99.900000       1.233333
# 2024-08-03    0.63      81.0      73.0    81.0  99.200000       1.224691
# 2024-08-04    0.63      81.0      72.0    81.0  98.500000       1.216049
# 2024-08-05    1.54      81.0      73.0    81.0  97.800000       1.207407
# 2024-08-06    0.20      81.0      72.0    81.0  97.100000       1.198765
#
#              max_min
# DATE
# 2014-09-08  1.126761
# 2014-09-09  1.154930
# ...
